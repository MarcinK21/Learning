# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# # Metoda Plot

# %%
bar = pd.read_csv("./data/weather_barcelona.csv", index_col = "Date")
rom = pd.read_csv("./data/weather_rome.csv", index_col = 'Date')
ams = pd.read_csv("./data/weather_amsterdam.csv", index_col = 'Date')
bar.head()
# Out:
#             TempMax  TempMin  Rain  AvgTempMax  AvgTempMin
# Date
# 2018-01-01       17       11     0          13           7
# 2018-01-02       19        8     0          13           7
# 2018-01-03       23       11     0          13           7
# 2018-01-04       24       15     0          13           7
# 2018-01-05       20       10     0          13           7

# %%
bar.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bar['TempMax'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bar.plot(y = 'TempMax')
# Out:
# <Axes: xlabel='Date'>

# %%
bar[['TempMax', 'TempMin']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bar.plot(y = ['TempMax', 'TempMin'])
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Zadania

# %%
import datetime

# import data
nasa = pd.read_csv("./data/nasa_facebook_statuses.csv", usecols = ['status_published', 'num_reactions', 'num_comments', 'num_shares', 'num_likes'])

# convert column type to date time

nasa['status_published'] = pd.to_datetime(nasa['status_published'])

# select observations beetwen two datetimes - May 2015 

filter = ( nasa['status_published'] >= '2016-5-1' ) & ( nasa['status_published'] < '2016-6-1' )

nasa = nasa[filter]

# add column with day only

nasa['day'] = nasa.apply(lambda row: row['status_published'].day, axis = 1)

# group all columns by sum

nasa_by_day = nasa.groupby(by = 'day').sum()

nasa_by_day.head()
# Out:
# C:\Users\neks5\AppData\Local\Temp\ipykernel_2336\2143251302.py:22: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   nasa_by_day = nasa.groupby(by = 'day').sum()
#      num_reactions  num_comments  num_shares  num_likes
# day
# 1            62629           727        4403      60243
# 2           188255          2328       23897     177989
# 3            53700           770       10858      50264
# 4           140098          1776       23360     133302
# 5            93146          1070        7627      89657

# %%
nasa_by_day.plot()
# Out:
# <Axes: xlabel='day'>

# %% [markdown]
# # Parametry metody Plot

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
bar = pd.read_csv("./data/weather_barcelona.csv", index_col = "Date")
rom = pd.read_csv("./data/weather_rome.csv", index_col = 'Date')
ams = pd.read_csv("./data/weather_amsterdam.csv", index_col = 'Date')
bar.head()
# Out:
#             TempMax  TempMin  Rain  AvgTempMax  AvgTempMin
# Date
# 2018-01-01       17       11     0          13           7
# 2018-01-02       19        8     0          13           7
# 2018-01-03       23       11     0          13           7
# 2018-01-04       24       15     0          13           7
# 2018-01-05       20       10     0          13           7

# %%
temp_max = pd.DataFrame(index = bar.index)

# %%
temp_max['Barcelona'] = bar['TempMax']
temp_max['Rome'] = rom['TempMax']
temp_max['Amsterdam'] = ams['TempMax']
temp_max.head()
# Out:
#             Barcelona  Rome  Amsterdam
# Date
# 2018-01-01         17    14          8
# 2018-01-02         19    13          9
# 2018-01-03         23    14         11
# 2018-01-04         24    16         11
# 2018-01-05         20    17          8

# %%
temp_max.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
temp_max.plot(figsize = (15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
temp_max.plot(figsize = (15,5), subplots = True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
temp_max.plot(figsize = (15,5), use_index = False)
# Out:
# <Axes: >

# %%
temp_max.plot(figsize = (15,5), title = 'Max temperature by city')
# Out:
# <Axes: title={'center': 'Max temperature by city'}, xlabel='Date'>

# %%
temp_max.plot(figsize = (15,5), legend = False)
# Out:
# <Axes: xlabel='Date'>

# %%
temp_max.plot(figsize = (15,5), logy = True)
# Out:
# <Axes: xlabel='Date'>

# %%
temp_max[:14].plot(figsize = (15,5), xticks = (range(14)), rot = 45)
# Out:
# <Axes: xlabel='Date'>

# %%
temp_max[:7].plot(figsize = (15,5), table = True)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Formatowanie wykresu

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
bar = pd.read_csv("./data/weather_barcelona.csv", index_col = "Date")
rom = pd.read_csv("./data/weather_rome.csv", index_col = 'Date')
ams = pd.read_csv("./data/weather_amsterdam.csv", index_col = 'Date')
bar.head()
# Out:
#             TempMax  TempMin  Rain  AvgTempMax  AvgTempMin
# Date
# 2018-01-01       17       11     0          13           7
# 2018-01-02       19        8     0          13           7
# 2018-01-03       23       11     0          13           7
# 2018-01-04       24       15     0          13           7
# 2018-01-05       20       10     0          13           7

# %%
temp_max = pd.DataFrame(index = bar.index)

# %%
temp_max['Barcelona'] = bar['TempMax']
temp_max['Rome'] = rom['TempMax']
temp_max['Amsterdam'] = ams['TempMax']
temp_max.head()
# Out:
#             Barcelona  Rome  Amsterdam
# Date
# 2018-01-01         17    14          8
# 2018-01-02         19    13          9
# 2018-01-03         23    14         11
# 2018-01-04         24    16         11
# 2018-01-05         20    17          8

# %%
bar.head()
# Out:
#             TempMax  TempMin  Rain  AvgTempMax  AvgTempMin
# Date
# 2018-01-01       17       11     0          13           7
# 2018-01-02       19        8     0          13           7
# 2018-01-03       23       11     0          13           7
# 2018-01-04       24       15     0          13           7
# 2018-01-05       20       10     0          13           7

# %%
bar.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bar.plot(color = ['b', 'g', 'r', 'm', 'k'])
# Out:
# <Axes: xlabel='Date'>

# %%
bar.plot(colormap = 'gnuplot')
# Out:
# <Axes: xlabel='Date'>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fast')
bar.plot(grid = False)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Wykres kołowy

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
bar = pd.read_csv("./data/weather_barcelona.csv", index_col = "Date")
rom = pd.read_csv("./data/weather_rome.csv", index_col = 'Date')
ams = pd.read_csv("./data/weather_amsterdam.csv", index_col = 'Date')
bar.head()
# Out:
#             TempMax  TempMin  Rain  AvgTempMax  AvgTempMin
# Date
# 2018-01-01       17       11     0          13           7
# 2018-01-02       19        8     0          13           7
# 2018-01-03       23       11     0          13           7
# 2018-01-04       24       15     0          13           7
# 2018-01-05       20       10     0          13           7

# %%
temp_max = pd.DataFrame(index = bar.index)

# %%
temp_max['Barcelona'] = bar['TempMax']
temp_max['Rome'] = rom['TempMax']
temp_max['Amsterdam'] = ams['TempMax']
temp_max.head()
# Out:
#             Barcelona  Rome  Amsterdam
# Date
# 2018-01-01         17    14          8
# 2018-01-02         19    13          9
# 2018-01-03         23    14         11
# 2018-01-04         24    16         11
# 2018-01-05         20    17          8

# %%
def GradeDay(row):
    if( row["TempMax"] >= row["AvgTempMax"] ):
        return 'PLUS'
    return 'MINUS'

# %%
rom['GradeDay'] = rom.apply(GradeDay, axis = 1)
bar['GradeDay'] = bar.apply(GradeDay, axis = 1)
ams['GradeDay'] = ams.apply(GradeDay, axis = 1)

# %%
rom.head()
# Out:
#             TempMax  TempMin Rain  AvgTempMax  AvgTempMin GradeDay
# Date
# 2018-01-01       14        8   0           12           4     PLUS
# 2018-01-02       13        7   0           12           4     PLUS
# 2018-01-03       14        1   0           12           4     PLUS
# 2018-01-04       16        6   0           12           4     PLUS
# 2018-01-05       17        7   0           12           3     PLUS

# %%
rom['GradeDay'].value_counts()
# Out:
# PLUS     70
# MINUS    20
# Name: GradeDay, dtype: int64

# %%
cities3 = pd.DataFrame(index = ['MINUS', 'PLUS'])
cities3['Barcelona'] = bar['GradeDay'].value_counts()
cities3['Rome'] = rom['GradeDay'].value_counts()
cities3['Amsterdam'] = ams['GradeDay'].value_counts()

# %%
cities3
# Out:
#        Barcelona  Rome  Amsterdam
# MINUS         26    20         22
# PLUS          64    70         68

# %%
cities3['Barcelona'].plot(kind = 'pie', figsize = (3,3))
# Out:
# <Axes: ylabel='Barcelona'>

# %%
cities3.plot(kind = 'pie', subplots = True, figsize = (10,10), legend = False, colors = ['b', 'g'], labels = ['colder', 'warmer'],
             autopct = '%.0f%%', fontsize = 15, textprops = dict(color = 'w'), layout = (2,2), explode = (0.1,0))
# Out:
# array([[<Axes: ylabel='Barcelona'>, <Axes: ylabel='Rome'>],
#        [<Axes: ylabel='Amsterdam'>, <Axes: >]], dtype=object)

# %% [markdown]
# # Wykres słupkowy, skrzynkowy i histogram

# %%
bar = pd.read_csv("./data/weather_barcelona.csv", index_col = 'Date')
rom = pd.read_csv("./data/weather_rome.csv", index_col = 'Date')
ams = pd.read_csv("./data/weather_amsterdam.csv", index_col= 'Date')

temp_max = pd.DataFrame(index = bar.index)

temp_max['Barcelona'] = bar['TempMax']
temp_max['Rome'] = rom['TempMax']
temp_max['Amsterdam'] = ams['TempMax']

# %%
def GradeDay(row):
    if ( row["TempMax"] >= row["AvgTempMax"] ):
        return 'PLUS'
    return 'MINUS'

# %%
rom['GradeDay'] = rom.apply(GradeDay, axis = 1)
bar['GradeDay'] = bar.apply(GradeDay, axis = 1)
ams['GradeDay'] = ams.apply(GradeDay, axis = 1)

# %%
cities3 = pd.DataFrame(index = ['MINUS', 'PLUS'])
cities3['Barcelona'] = bar['GradeDay'].value_counts()
cities3['Rome'] = rom['GradeDay'].value_counts()
cities3['Amsterdam'] = ams['GradeDay'].value_counts()
cities3
# Out:
#        Barcelona  Rome  Amsterdam
# MINUS         26    20         22
# PLUS          64    70         68

# %%
cities3["Barcelona"].plot(kind = 'bar', rot = 45, figsize = (3,3))
# Out:
# <Axes: >

# %%
cities3["Barcelona"].plot(kind = 'barh', rot = 45, figsize = (3,3))
# Out:
# <Axes: >

# %%
cities3.plot(kind = 'bar', rot = 45, figsize = (3,3))
# Out:
# <Axes: >

# %%
cities3.plot(kind = 'bar', rot = 45, figsize = (3,3), stacked = True)
# Out:
# <Axes: >

# %%
temp_max.head()
# Out:
#             Barcelona  Rome  Amsterdam
# Date
# 2018-01-01         17    14          8
# 2018-01-02         19    13          9
# 2018-01-03         23    14         11
# 2018-01-04         24    16         11
# 2018-01-05         20    17          8

# %%
temp_max.plot(kind ='box')
# Out:
# <Axes: >

# %%
color = dict(boxes = 'DarkGreen', whiskers = 'DarkOrange', medians = 'DarkBlue', caps = 'Gray')

# %%
temp_max.plot(kind ='box', color = color)
# Out:
# <Axes: >

# %%
bar['TempMax'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
bar['TempMax'].value_counts().sort_index()
# Out:
# 5      1
# 7      1
# 9      1
# 10     3
# 11     4
# 12     8
# 13     4
# 14    10
# 15    17
# 16    11
# 17     9
# 18     8
# 19     4
# 20     4
# 21     1
# 22     1
# 23     1
# 24     2
# Name: TempMax, dtype: int64

# %%
bar['TempMax'].nunique()
# Out:
# 18

# %%
bar['TempMax'].plot(kind = 'hist', bins = 18, figsize  = (10,3), rot = 45, xticks = bar['TempMax'], edgecolor = 'black', width = 0.7)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Wykresy scatter, hexbin, area

# %%
autos = pd.read_csv('./data/autos.csv', encoding = 'latin-1')
autos.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# ...

# %%
import re
regex = re.compile('.*toyota.*corolla.*', re.IGNORECASE)
filter1 = autos['name'].apply(lambda x: bool(regex.search(x)))
filter2 = autos['price'] < 12000
filter3 = autos['yearOfRegistration'] >= 1990

# %%
tc = autos[filter1 & filter2 & filter3]
tc.head()
# Out:
#               dateCrawled                                          name  \
# 861   2016-03-07 13:46:32                  Toyota_Corolla_1.6_Combi_Sol
# 912   2016-03-27 23:53:18  Toyota_Corolla_Verso_2.2_D_CAT_DPF_Executive
# 1898  2016-03-22 20:52:00                                Toyota_Corolla
# 2264  2016-03-12 23:47:09            Toyota_Corolla_1.6_VVT_i_Combi_Sol
# 2386  2016-03-10 14:48:16            Toyota_Corolla_Verso_2.2_D_CAT_Sol
#
#       seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 861   privat   Angebot   1800  control       kombi                2003
# 912   privat   Angebot   5300     test         bus                2008
# 1898  privat   Angebot   3200  control  kleinwagen                2004
# 2264  privat   Angebot   2990  control       kombi                2004
# 2386  privat   Angebot   5900     test         bus                2006
#
#       gearbox  powerPS    model  kilometer  monthOfRegistration fuelType  \
# ...

# %%
import re
regex = re.compile('.*Audi.*a4.*', re.IGNORECASE)
filter1 = autos['name'].apply(lambda x: bool(regex.search(x)))
filter2 = autos['price'] < 12000
filter3 = autos['yearOfRegistration'] >= 1990

audi = autos[filter1 & filter2 & filter3]

# %%
audi.head()
# Out:
#              dateCrawled                             name  seller offerType  \
# 103  2016-03-15 17:41:31             Audi_A4_B5_1_6_Liter  privat   Angebot
# 105  2016-04-01 09:54:39  Audi_a4_2.5_TDI_Tausch_moeglich  privat   Angebot
# 147  2016-03-14 12:46:46       Audi_A4_b5_Avant_TÜV_10/17  privat   Angebot
# 316  2016-03-19 10:54:59            Audi_A4_Cabriolet_3.0  privat   Angebot
# 408  2016-03-20 23:45:11                      Audi_A4_1.8  privat   Angebot
#
#      price   abtest vehicleType  yearOfRegistration  gearbox  powerPS model  \
# 103    499  control   limousine                1995  manuell      101    a4
# 105   6500     test   limousine                2004  manuell      163    a4
# 147   1500     test       kombi                1996  manuell      126    a4
# 316   5299     test      cabrio                2002  manuell      220    a4
# 408   2700  control   limousine                1999  manuell      125    a4
#
# ...

# %%
tc.plot(kind = 'scatter', x='yearOfRegistration', y='price')
# Out:
# <Axes: xlabel='yearOfRegistration', ylabel='price'>

# %%
audi.plot(kind = 'scatter', x='yearOfRegistration', y='price')
# Out:
# <Axes: xlabel='yearOfRegistration', ylabel='price'>

# %%
ax = audi.plot.scatter(x = 'yearOfRegistration', y = 'price', color = 'Blue', label = 'Adui')
tc.plot.scatter(x = 'yearOfRegistration', y = 'price', color = 'Green', label = 'Toyota', ax = ax)
# Out:
# <Axes: xlabel='yearOfRegistration', ylabel='price'>

# %%
tc.plot.hexbin(x = 'yearOfRegistration', y = 'price', gridsize = 10, title = 'Toyota', figsize = (3,3))
audi.plot.hexbin(x = 'yearOfRegistration', y = 'price', gridsize = 10, title = 'Audi', figsize = (3,3))
# Out:
# <Axes: title={'center': 'Audi'}, xlabel='yearOfRegistration', ylabel='price'>

# %%
tc_counts = tc['yearOfRegistration'].value_counts().sort_index()
tc_counts.head()
# Out:
# 1990     6
# 1991     4
# 1992     5
# 1993    12
# 1994     3
# Name: yearOfRegistration, dtype: int64

# %%
audi_counts = audi['yearOfRegistration'].value_counts().sort_index()
audi_counts.head()
# Out:
# 1992      1
# 1993      1
# 1994     39
# 1995    458
# 1996    609
# Name: yearOfRegistration, dtype: int64

# %%
car_counts = pd.DataFrame(index = tc_counts.index.append(audi_counts.index).unique())
car_counts['Toyota'] = tc_counts
car_counts['Audi'] = audi_counts
car_counts.head()
# Out:
#       Toyota  Audi
# 1990     6.0   NaN
# 1991     4.0   NaN
# 1992     5.0   1.0
# 1993    12.0   1.0
# 1994     3.0  39.0

# %%
car_counts.fillna(0, inplace = True)

# %%
car_counts.sort_index(inplace = True)
car_counts.head()
# Out:
#       Toyota  Audi
# 1990     6.0   0.0
# 1991     4.0   0.0
# 1992     5.0   1.0
# 1993    12.0   1.0
# 1994     3.0  39.0

# %%
car_counts.plot()
# Out:
# <Axes: >

# %%
car_counts.plot(kind = 'area')
# Out:
# <Axes: >
