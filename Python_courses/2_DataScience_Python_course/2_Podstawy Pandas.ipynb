# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # DATA SERIES

# %%
s = pd.Series(data = [3, 2, 4, 6])
s
# Out:
# 0    3
# 1    2
# 2    4
# 3    6
# dtype: int64

# %%
s = pd.Series(data = [3, 2, 4, 6], index = ['a','b','c','d'], name = 'sample')
s
# Out:
# a    3
# b    2
# c    4
# d    6
# Name: sample, dtype: int64

# %%
s = pd.Series(data = [3, np.nan, 4, 6], index = ['a','b','c','d'], name = 'sample')
s
# Out:
# a    3.0
# b    NaN
# c    4.0
# d    6.0
# Name: sample, dtype: float64

# %%
s = pd.Series(data =[True, False, False])
s
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
s = pd.Series(data = np.arange(10,20), index = pd.date_range(start = '20200101', periods = 10))
s
# Out:
# 2020-01-01    10
# 2020-01-02    11
# 2020-01-03    12
# 2020-01-04    13
# 2020-01-05    14
# 2020-01-06    15
# 2020-01-07    16
# 2020-01-08    17
# 2020-01-09    18
# 2020-01-10    19
# Freq: D, dtype: int64

# %%
s = pd.Series(['python', 'java', 'sql'], name = 'languages')
s
# Out:
# 0    python
# 1      java
# 2       sql
# Name: languages, dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s.values
# Out:
# array(['python', 'java', 'sql'], dtype=object)

# %%
s.value_counts()
# Out:
# python    1
# java      1
# sql       1
# Name: languages, dtype: int64

# %%
price = pd.Series(data = {'Apple' : 200, 'CD Projekt' : 60, 'Amazon' : 1900, 'KGHM': np.nan})
price
# Out:
# Apple          200.0
# CD Projekt      60.0
# Amazon        1900.0
# KGHM             NaN
# dtype: float64

# %%
price['CD Projekt']
# Out:
# 60

# %%
price[1]
# Out:
# 60

# %%
price.count()
# Out:
# 3

# %%
price.value_counts(dropna = False)
# Out:
# 200.0     1
# 60.0      1
# 1900.0    1
# NaN       1
# dtype: int64

# %%
price.describe()
# Out:
# count       3.000000
# mean      720.000000
# std      1024.304642
# min        60.000000
# 25%       130.000000
# 50%       200.000000
# 75%      1050.000000
# max      1900.000000
# dtype: float64

# %%
price.nlargest(1)
# Out:
# Amazon    1900.0
# dtype: float64

# %%
price.nsmallest(1)
# Out:
# CD Projekt    60.0
# dtype: float64

# %%
price.rank()
# Out:
# Apple         2.0
# CD Projekt    1.0
# Amazon        3.0
# KGHM          NaN
# dtype: float64

# %%
price.sort_values()
# Out:
# CD Projekt      60.0
# Apple          200.0
# Amazon        1900.0
# KGHM             NaN
# dtype: float64

# %%
price.sort_values(ascending = False)
# Out:
# Amazon        1900.0
# Apple          200.0
# CD Projekt      60.0
# KGHM             NaN
# dtype: float64

# %% [markdown]
# # Metoda apply

# %%
price.apply(lambda x: x * 3.8)
# Out:
# Apple          760.0
# CD Projekt     228.0
# Amazon        7220.0
# KGHM             NaN
# dtype: float64

# %%
price_pln = price.apply(lambda x: x * 3.8)
price_pln
# Out:
# Apple          760.0
# CD Projekt     228.0
# Amazon        7220.0
# KGHM             NaN
# dtype: float64

# %% [markdown]
# # DATA FRAME

# %%
df = pd.DataFrame(data = [12,12,32])
df
# Out:
#     0
# 0  12
# 1  12
# 2  32

# %%
df = pd.DataFrame(data = [12,12,32], index = ['first', 'second', 'third'], columns = ['col_1'])
df
# Out:
#         col_1
# first      12
# second     12
# third      32

# %%
df = pd.DataFrame(data = {'WIG20': ['PKN ORLEN', 'PKO BP'],
                          'mWIG40' : ['Amica', 'Playway']})
df
# Out:
#        WIG20   mWIG40
# 0  PKN ORLEN    Amica
# 1     PKO BP  Playway

# %%
df = pd.DataFrame(data = [[10, 12, 13], [23, 12, 10]], index = ['first', 'second'], columns = ['col_1', 'col_2', 'col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %%
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %%
df.values
# Out:
# array([[10, 12, 13],
#        [23, 12, 10]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, first to second
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_1   2 non-null      int64
#  1   col_2   2 non-null      int64
#  2   col_3   2 non-null      int64
# dtypes: int64(3)
# memory usage: 172.0+ bytes

# %%
df.describe()
# Out:
#            col_1  col_2     col_3
# count   2.000000    2.0   2.00000
# mean   16.500000   12.0  11.50000
# std     9.192388    0.0   2.12132
# min    10.000000   12.0  10.00000
# 25%    13.250000   12.0  10.75000
# 50%    16.500000   12.0  11.50000
# 75%    19.750000   12.0  12.25000
# max    23.000000   12.0  13.00000

# %%
df.describe().T
# Out:
#        count  mean       std   min    25%   50%    75%   max
# col_1    2.0  16.5  9.192388  10.0  13.25  16.5  19.75  23.0
# col_2    2.0  12.0  0.000000  12.0  12.00  12.0  12.00  12.0
# col_3    2.0  11.5  2.121320  10.0  10.75  11.5  12.25  13.0

# %%
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %%
df['col_1'] # wycinamy z obiektu DataFrame obiekt typu DataSeries
# Out:
# first     10
# second    23
# Name: col_1, dtype: int64

# %%
df[['col_1']] # podwójny nawias kwadratowy spawia że z DataFrame wciągam obiektu typu DataFrame
# Out:
#         col_1
# first      10
# second     23

# %%
df.columns = ['a', 'b', 'c']
df
# Out:
#          a   b   c
# first   10  12  13
# second  23  12  10

# %%
df.a # sposób na zwrócienie obiektu typu Series z DataFrame
# Out:
# first     10
# second    23
# Name: a, dtype: int64

# %%
# metoda loc[] pozwala wycinać po nazwach
# metoda iloc[] pozwala wyniać po numerze indeksie

# %%
df = pd.DataFrame(data = [[10,12,13], [23,12,10]], index = ['first', 'second'], columns = ['col_1','col_2','col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %%
df.loc['first']
# Out:
# col_1    10
# col_2    12
# col_3    13
# Name: first, dtype: int64

# %%
df.loc['first', 'col_2']
# Out:
# 12

# %%
df.loc[:,'col_2']
# Out:
# first     12
# second    12
# Name: col_2, dtype: int64

# %%
df.iloc[0]
# Out:
# col_1    10
# col_2    12
# col_3    13
# Name: first, dtype: int64

# %%
df.iloc[0, 1]
# Out:
# 12

# %%
df.iloc[:, 1]
# Out:
# first     12
# second    12
# Name: col_2, dtype: int64

# %% [markdown]
# # Case study 1

# %%
import pandas as pd
import numpy as np

print(f'Numpy: {np.__version__}')
print(f'Pandas: {pd.__version__}')
# Out:
# Numpy: 1.23.5
# Pandas: 1.5.3

# %%
pip install pandas_datareader

# %% [markdown]
# # Załadowanie danych

# %%
# Załadowanie danych
def fetch_financial_data(company='AMZN'):
    """Pobiera dane dotyczące notowań spółek na giełdzie według symboli na serwisie stooq.pl"""
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df = fetch_financial_data()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1256 entries, 2023-09-13 to 2018-09-17
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1256 non-null   float64
#  1   High    1256 non-null   float64
#  2   Low     1256 non-null   float64
#  3   Close   1256 non-null   float64
#  4   Volume  1256 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
df.head()
# Out:
#               Open      High     Low   Close    Volume
# Date
# 2023-09-11  138.75  143.6200  138.64  143.10  56764525
# 2023-09-08  136.86  138.8519  136.75  138.23  38365929
# 2023-09-07  133.90  138.0300  133.16  137.85  48498912
# 2023-09-06  136.32  137.4500  134.61  135.36  41785507
# 2023-09-05  137.73  137.8000  135.82  137.27  40636738

# %%
df.columns = [col.lower() for col in df.columns]
df.head()
# Out:
#               open      high     low   close    volume
# Date
# 2023-09-11  138.75  143.6200  138.64  143.10  56764525
# 2023-09-08  136.86  138.8519  136.75  138.23  38365929
# 2023-09-07  133.90  138.0300  133.16  137.85  48498912
# 2023-09-06  136.32  137.4500  134.61  135.36  41785507
# 2023-09-05  137.73  137.8000  135.82  137.27  40636738

# %%
df.describe()
# Out:
#               open         high          low        close        volume
# count  1256.000000  1256.000000  1256.000000  1256.000000  1.256000e+03
# mean    124.488971   126.037491   122.810324   124.431218  8.121303e+07
# std      32.661147    32.950812    32.305630    32.590200  3.826754e+07
# min      67.300000    69.801500    65.350000    67.198000  1.762674e+07
# 25%      93.540500    94.683750    92.454000    93.488375  5.574893e+07
# 50%     119.356500   121.365100   117.720000   120.013500  6.984755e+07
# 75%     158.341000   159.953500   156.254750   158.102000  9.549421e+07
# max     187.200000   188.654000   184.840000   186.570000  3.113457e+08

# %% [markdown]
# # Selekcja kolumn

# %%
# Selekcja kolumn
df = df.head(10)
df
# Out:
#                open      high      low   close    volume
# Date
# 2023-09-11  138.750  143.6200  138.640  143.10  56764525
# 2023-09-08  136.860  138.8519  136.750  138.23  38365929
# 2023-09-07  133.900  138.0300  133.160  137.85  48498912
# 2023-09-06  136.320  137.4500  134.610  135.36  41785507
# 2023-09-05  137.730  137.8000  135.820  137.27  40636738
# 2023-09-01  139.455  139.9600  136.875  138.12  40991536
# 2023-08-31  135.060  138.7885  135.000  138.01  58781314
# 2023-08-30  134.930  135.6800  133.920  135.07  36137015
# 2023-08-29  133.380  135.1400  133.250  134.91  38646093
# 2023-08-28  133.780  133.9500  131.850  133.14  34108410

# %%
df[['open']]
# Out:
#                open
# Date
# 2023-09-11  138.750
# 2023-09-08  136.860
# 2023-09-07  133.900
# 2023-09-06  136.320
# 2023-09-05  137.730
# 2023-09-01  139.455
# 2023-08-31  135.060
# 2023-08-30  134.930
# 2023-08-29  133.380
# 2023-08-28  133.780

# %%
df[['open', 'close']]
# Out:
#                open   close
# Date
# 2023-09-11  138.750  143.10
# 2023-09-08  136.860  138.23
# 2023-09-07  133.900  137.85
# 2023-09-06  136.320  135.36
# 2023-09-05  137.730  137.27
# 2023-09-01  139.455  138.12
# 2023-08-31  135.060  138.01
# 2023-08-30  134.930  135.07
# 2023-08-29  133.380  134.91
# 2023-08-28  133.780  133.14

# %%
df.iloc[:, 0]
# Out:
# Date
# 2023-09-11    138.750
# 2023-09-08    136.860
# 2023-09-07    133.900
# 2023-09-06    136.320
# 2023-09-05    137.730
# 2023-09-01    139.455
# 2023-08-31    135.060
# 2023-08-30    134.930
# 2023-08-29    133.380
# 2023-08-28    133.780
# Name: open, dtype: float64

# %% [markdown]
# # Obliczanie nowych kolumn

# %%
# obliczanie nowych kolumn
df = fetch_financial_data('UBER')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1094 entries, 2023-09-13 to 2019-05-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1094 non-null   float64
#  1   High    1094 non-null   float64
#  2   Low     1094 non-null   float64
#  3   Close   1094 non-null   float64
#  4   Volume  1094 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 51.3 KB

# %%
df.head()
# Out:
#              Open     High    Low  Close    Volume
# Date
# 2023-09-13  47.51  48.3599  47.28  48.16  12691849
# 2023-09-12  48.34  49.1881  47.90  47.92  18808980
# 2023-09-11  47.74  48.9700  47.65  48.94  19007314
# 2023-09-08  46.34  47.2500  46.27  47.24  15965207
# 2023-09-07  45.50  46.6800  45.25  46.27  14972153

# %%
df.describe().T
# Out:
#          count          mean           std         min           25%  \
# Open    1094.0  3.748464e+01  9.389247e+00       15.96  3.051250e+01
# High    1094.0  3.824169e+01  9.464576e+00       17.80  3.111875e+01
# Low     1094.0  3.668575e+01  9.256799e+00       13.71  2.983000e+01
# Close   1094.0  3.746937e+01  9.343844e+00       14.82  3.046000e+01
# Volume  1094.0  2.517169e+07  1.613171e+07  3380003.00  1.580312e+07
#
#                  50%           75%           max
# Open    3.545500e+01  4.419750e+01  6.325000e+01
# High    3.630900e+01  4.495375e+01  6.405000e+01
# Low     3.451250e+01  4.351750e+01  6.080000e+01
# Close   3.526000e+01  4.415750e+01  6.318000e+01
# Volume  2.136189e+07  2.975147e+07  1.863225e+08

# %%
df.columns = [col.lower() for col in df.columns]
df['Average'] = ( df['open'] + df['close'] ) / 2
df.head()
# Out:
#              open     high    low  close    volume  Average
# Date
# 2023-09-13  47.51  48.3599  47.28  48.16  12691849   47.835
# 2023-09-12  48.34  49.1881  47.90  47.92  18808980   48.130
# 2023-09-11  47.74  48.9700  47.65  48.94  19007314   48.340
# 2023-09-08  46.34  47.2500  46.27  47.24  15965207   46.790
# 2023-09-07  45.50  46.6800  45.25  46.27  14972153   45.885

# %%
df.sort_index(inplace = True)
df.head()
# Out:
#              open   high    low  close     volume  Average
# Date
# 2019-05-10  42.00  45.00  41.06  41.57  186322536   41.785
# 2019-05-13  38.79  39.24  36.08  37.10   79442420   37.945
# 2019-05-14  38.31  39.96  36.85  39.96   46661147   39.135
# 2019-05-15  39.37  41.88  38.95  41.29   36086065   40.330
# 2019-05-16  41.48  44.06  41.25  43.00   38115524   42.240

# %%
df['close_shift'] = df['close'].shift(1)

# %%
df.head()
# Out:
#              open   high    low  close     volume  Average  close_shift
# Date
# 2019-05-10  42.00  45.00  41.06  41.57  186322536   41.785          NaN
# 2019-05-13  38.79  39.24  36.08  37.10   79442420   37.945        41.57
# 2019-05-14  38.31  39.96  36.85  39.96   46661147   39.135        37.10
# 2019-05-15  39.37  41.88  38.95  41.29   36086065   40.330        39.96
# 2019-05-16  41.48  44.06  41.25  43.00   38115524   42.240        41.29

# %%
df['daily_change'] = df['close'] / df['close_shift'] -1
df.head()
# Out:
#              open   high    low  close     volume  Average  close_shift  \
# Date
# 2019-05-10  42.00  45.00  41.06  41.57  186322536   41.785          NaN
# 2019-05-13  38.79  39.24  36.08  37.10   79442420   37.945        41.57
# 2019-05-14  38.31  39.96  36.85  39.96   46661147   39.135        37.10
# 2019-05-15  39.37  41.88  38.95  41.29   36086065   40.330        39.96
# 2019-05-16  41.48  44.06  41.25  43.00   38115524   42.240        41.29
#
#             daily_change
# Date
# 2019-05-10           NaN
# 2019-05-13     -0.107529
# 2019-05-14      0.077089
# 2019-05-15      0.033283
# 2019-05-16      0.041414

# %%
df.daily_change.min()
# df['daily_change'].min()
# Out:
# -0.21628767847699626

# %%
df.daily_change.max()
# df['daily_change'].max()
# Out:
# 0.3825910931174088

# %%
df['daily_change'].hist(bins=100)
# Out:
# <Axes: >

# %% [markdown]
# # Filtrowanie danych

# %%
# Filtrowanie danych
df_positive = df[df['daily_change'] > 0].head()
df_positive['daily_change'].mean()
# Out:
# 0.03856225984456172

# %%
df_negative = df[df['daily_change'] < 0].head()
df_negative['daily_change'].mean()
# Out:
# -0.029740358579608772

# %%
df.close == df.high
# Out:
# Date
# 2019-05-10    False
# 2019-05-13    False
# 2019-05-14     True
# 2019-05-15    False
# 2019-05-16    False
#               ...
# 2023-09-07    False
# 2023-09-08    False
# 2023-09-11    False
# 2023-09-12    False
# 2023-09-13    False
# Length: 1094, dtype: bool

# %%
df[df['close'] == df['high']]
# Out:
#              open   high    low  close    volume  Average  close_shift  \
# Date
# 2019-05-14  38.31  39.96  36.85  39.96  46661147   39.135        37.10
# 2019-05-24  41.28  41.51  40.50  41.51   8786751   41.395        40.47
# 2020-08-25  31.04  31.19  30.60  31.19  10056762   31.115        31.04
# 2020-12-04  52.71  54.86  52.71  54.86  22207887   53.785        52.52
# 2021-02-04  56.45  57.85  56.11  57.85  13847255   57.150        57.12
# 2022-11-30  27.80  29.14  27.64  29.14  18177028   28.470        27.76
#
#             daily_change
# Date
# 2019-05-14      0.077089
# 2019-05-24      0.025698
# 2020-08-25      0.004832
# 2020-12-04      0.044554
# 2021-02-04      0.012780
# 2022-11-30      0.049712

# %%
df[df['close'] == df['low']]
# Out:
#              open   high    low  close    volume  Average  close_shift  \
# Date
# 2019-08-12  39.84  39.95  37.00  37.00  20632310   38.420        40.05
# 2019-12-09  27.96  28.36  27.68  27.68  21098387   27.820        27.86
# 2019-12-27  30.80  31.06  30.17  30.17  18465965   30.485        30.67
# 2020-12-31  53.28  53.28  51.00  51.00  13282786   52.140        53.15
# 2021-12-31  42.53  43.12  41.93  41.93  13746893   42.230        42.66
# 2023-01-05  25.73  26.01  25.55  25.55   9942038   25.640        25.91
# 2023-05-16  37.93  38.15  37.44  37.44  21836864   37.685        38.14
# 2023-05-30  38.73  39.06  37.56  37.56  18143192   38.145        38.45
#
#             daily_change
# Date
# 2019-08-12     -0.076155
# 2019-12-09     -0.006461
# 2019-12-27     -0.016303
# 2020-12-31     -0.040452
# 2021-12-31     -0.017112
# 2023-01-05     -0.013894
# 2023-05-16     -0.018353
# 2023-05-30     -0.023147

# %%
df.index > '2019-11-01' #wszystkie sesje notowań po 1 listopada 2019 roku
# Out:
# array([False, False, False, ...,  True,  True,  True])

# %%
df[df.index > '2019-11-01']
# Out:
#              open     high     low  close     volume  Average  close_shift  \
# Date
# 2019-11-04  31.45  31.7500  30.120  31.08   32330121   31.265        31.37
# 2019-11-05  29.13  29.3000  27.970  28.02   52180615   28.575        31.08
# 2019-11-06  26.06  27.5500  25.580  26.94  133569790   26.500        28.02
# 2019-11-07  26.80  27.4200  26.450  27.38   65949472   27.090        26.94
# 2019-11-08  27.48  27.6200  26.915  27.01   45263118   27.245        27.38
# ...           ...      ...     ...    ...        ...      ...          ...
# 2023-09-07  45.50  46.6800  45.250  46.27   14972153   45.885        45.90
# 2023-09-08  46.34  47.2500  46.270  47.24   15965207   46.790        46.27
# 2023-09-11  47.74  48.9700  47.650  48.94   19007314   48.340        47.24
# 2023-09-12  48.34  49.1881  47.900  47.92   18808980   48.130        48.94
# 2023-09-13  47.51  48.3599  47.280  48.16   12691849   47.835        47.92
#
#             daily_change
# Date
# 2019-11-04     -0.009245
# ...

# %%
df[(df.index >= '2019-11-01') & (df.index <= '2019-11-15')] # & - and , | - or
# Out:
#              open   high      low  close     volume  Average  close_shift  \
# Date
# 2019-11-01  31.45  31.70  30.7412  31.37   10460430   31.410        31.50
# 2019-11-04  31.45  31.75  30.1200  31.08   32330121   31.265        31.37
# 2019-11-05  29.13  29.30  27.9700  28.02   52180615   28.575        31.08
# 2019-11-06  26.06  27.55  25.5800  26.94  133569790   26.500        28.02
# 2019-11-07  26.80  27.42  26.4500  27.38   65949472   27.090        26.94
# 2019-11-08  27.48  27.62  26.9150  27.01   45263118   27.245        27.38
# 2019-11-11  27.03  27.21  26.2300  27.14   41445732   27.085        27.01
# 2019-11-12  27.38  27.66  26.6600  26.70   37095389   27.040        27.14
# 2019-11-13  26.47  26.82  26.1400  26.71   34512663   26.590        26.70
# 2019-11-14  26.80  26.86  25.6650  25.99   28027875   26.395        26.71
# 2019-11-15  26.18  26.80  25.9550  26.79   41372771   26.485        25.99
#
#             daily_change
# Date
# 2019-11-01     -0.004127
# ...

# %% [markdown]
# # załadowanie danych

# %%
def fetch_financial_data(company = 'AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source ='stooq')

df = fetch_financial_data('FB')
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # London Bike Dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('london_bike.csv')
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df.set_index('timestamp', inplace = True)

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0
# 2015-01-04 03:00:00         0.0         1.0     3.0
# 2015-01-04 04:00:00         0.0         1.0     3.0

# %% [markdown]
# # Łączenie danych

# %%
def fetch_financial_data(company='AMZN'):
    import pandas_datareader.data as web
    return web.DataReader(name = company, data_source = 'stooq')

apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2023-09-14 to 2018-09-17
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1257 non-null   float64
#  1   High    1257 non-null   float64
#  2   Low     1257 non-null   float64
#  3   Close   1257 non-null   float64
#  4   Volume  1257 non-null   float64
# dtypes: float64(5)
# memory usage: 58.9 KB

# %%
apple.head()
# Out:
#               Open     High     Low   Close      Volume
# Date
# 2023-09-14  174.00  176.100  173.58  175.74  60895757.0
# 2023-09-13  176.51  177.300  173.98  174.21  84267928.0
# 2023-09-12  179.49  180.130  174.82  176.30  90370192.0
# 2023-09-11  180.07  180.300  177.34  179.36  58953052.0
# 2023-09-08  178.35  180.239  177.79  178.18  65602066.0

# %% [markdown]
# # Preprocessing

# %%
apple.columns = ['apple_' + col.lower() for col in apple.columns]
amazon.columns = ['amazon_' + col.lower() for col in amazon.columns]
google.columns = ['google_' + col.lower() for col in google.columns]
uber.columns = ['uber_' + col.lower() for col in uber.columns]

# %%
apple.head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2023-09-14      174.00     176.100     173.58       175.74    60895757.0
# 2023-09-13      176.51     177.300     173.98       174.21    84267928.0
# 2023-09-12      179.49     180.130     174.82       176.30    90370192.0
# 2023-09-11      180.07     180.300     177.34       179.36    58953052.0
# 2023-09-08      178.35     180.239     177.79       178.18    65602066.0

# %% [markdown]
# # Kontatenacja danych

# %%
pd.concat(objs = [apple, amazon, google, uber], axis = 1).head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume  \
# Date
# 2018-09-17     53.4151     53.6065    52.2426      52.3882  1.546865e+08
# 2018-09-18     52.3682     53.3463    52.2118      52.4769  1.312999e+08
# 2018-09-19     52.5407     52.8079    51.7691      52.5088  1.128021e+08
# 2018-09-20     52.9565     53.4449    52.6953      52.9036  1.106602e+08
# 2018-09-21     53.0880     53.2296    52.2486      52.3354  4.002694e+08
#
#             amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume  \
# Date
# 2018-09-17      97.7365      97.8410     94.3705       95.4015      141003840
# 2018-09-18      95.9325      97.9100     95.7720       97.0525       85374120
# 2018-09-19      97.0250      97.0415     95.2450       96.3210       81136440
# 2018-09-20      96.9290      97.7500     96.6125       97.2150       63098680
# 2018-09-21      97.7110      97.8655     95.5250       95.7505      137117960
#
# ...

# %%
df = pd.concat(objs = [apple, amazon, google, uber], axis = 1)
df.describe()

# %%
pd.set_option('display.float_format', lambda x: f'{x:.2f}')

df.describe().T
# df.corr() - wyświetli tablice z współczynnikiem korelacji dla poszczególnych kolumn
# Out:
#                 count         mean         std         min         25%  \
# apple_open    1257.00       114.12       47.35       34.74       64.34
# apple_high    1257.00       115.47       47.84       35.16       65.09
# apple_low     1257.00       112.86       46.88       34.26       63.88
# apple_close   1257.00       114.22       47.37       34.31       64.44
# apple_volume  1257.00 109816117.88 56672451.95 31458198.00 73566953.58
# amazon_open   1257.00       124.57       32.65       67.30       93.54
# amazon_high   1257.00       126.12       32.93       69.80       94.69
# amazon_low    1257.00       122.89       32.29       65.35       92.47
# amazon_close  1257.00       124.52       32.57       67.20       93.49
# amazon_volume 1257.00  81165836.53 38273749.40 17626740.00 55716880.00
# google_open   1257.00        93.50       29.92       49.22       63.58
# google_high   1257.00        94.59       30.21       50.61       64.04
# ...

# %%
closes = [col for col in df.columns if col.endswith('close')]
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'uber_close']

# %%
df[closes].head()
# Out:
#             apple_close  amazon_close  google_close  uber_close
# Date
# 2018-09-17        52.39         95.40         57.99         NaN
# 2018-09-18        52.48         97.05         58.36         NaN
# 2018-09-19        52.51         96.32         58.71         NaN
# 2018-09-20        52.90         97.22         59.58         NaN
# 2018-09-21        52.34         95.75         58.61         NaN

# %%
df[closes].corr()
# Out:
#               apple_close  amazon_close  google_close  uber_close
# apple_close          1.00          0.60          0.91        0.13
# amazon_close         0.60          1.00          0.71        0.58
# google_close         0.91          0.71          1.00        0.28
# uber_close           0.13          0.58          0.28        1.00

# %%
closes_vol = [col for col in df.columns if col.endswith('close') or col.endswith('volume')]
closes_vol
# Out:
# ['apple_close',
#  'apple_volume',
#  'amazon_close',
#  'amazon_volume',
#  'google_close',
#  'google_volume',
#  'uber_close',
#  'uber_volume']

# %%
df[closes_vol].corr()
# Out:
#                apple_close  apple_volume  amazon_close  amazon_volume  \
# apple_close           1.00         -0.48          0.60          -0.35
# apple_volume         -0.48          1.00         -0.18           0.62
# amazon_close          0.60         -0.18          1.00          -0.21
# amazon_volume        -0.35          0.62         -0.21           1.00
# google_close          0.91         -0.48          0.71          -0.36
# google_volume        -0.10          0.46         -0.13           0.55
# uber_close            0.13         -0.19          0.58          -0.19
# uber_volume           0.06          0.23         -0.04           0.25
#
#                google_close  google_volume  uber_close  uber_volume
# apple_close            0.91          -0.10        0.13         0.06
# apple_volume          -0.48           0.46       -0.19         0.23
# amazon_close           0.71          -0.13        0.58        -0.04
# ...

# %% [markdown]
# # Łączenie danych - metoda append

# %%
uber_6 = uber[uber.index.month == 6]
uber_6.head()
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2023-06-30      43.11      43.43     42.92       43.17     17589240
# 2023-06-29      44.09      44.28     42.11       42.58     28595285
# 2023-06-28      43.50      45.24     43.32       44.24     28187374
# 2023-06-27      44.69      44.83     43.75       43.83     29652066
# 2023-06-26      43.75      45.04     43.68       44.42     33692974

# %%
uber_7 = uber[uber.index.month == 7]
uber_7.head()
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2023-07-31      48.85      49.49     48.15       49.46     38736789
# 2023-07-28      47.14      48.43     46.71       48.14     17154631
# 2023-07-27      48.00      48.09     46.35       46.61     17991953
# 2023-07-26      47.05      47.55     46.62       47.31     16666161
# 2023-07-25      47.20      47.73     46.93       47.17     14188200

# %%
uber_67 = uber_6.append(uber_7)
# Out:
# <ipython-input-32-8413063b5ca4>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   uber_67 = uber_6.append(uber_7)

# %% [markdown]
# # Case Study II - Google App Store Data

# %%
# 1. Import bibliotek
# 2. Załadowanie danych
# 3. Wstępne przygotowanie danych - preprocessing
# 4. Jak zbadać rozkład zmiennej?
# 5. Sprawdzanie braków w danych

# %%
import pandas as pd

# %%
url = 'https://storage.googleapis.com/esmartdata-courses-files/ds-bootcamp/appstore_games.csv'
df_raw = pd.read_csv(url)
df_raw.head()
# Out:
#                                                  URL         ID  \
# 0   https://apps.apple.com/us/app/sudoku/id284921427  284921427
# 1  https://apps.apple.com/us/app/reversi/id284926400  284926400
# 2  https://apps.apple.com/us/app/morocco/id284946595  284946595
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  285755462
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  285831220
#
#             Name Subtitle                                           Icon URL  \
# 0         Sudoku      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1        Reversi      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2        Morocco      NaN  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  Sudoku (Free)      NaN  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4   Senet Deluxe      NaN  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# ...

# %% [markdown]
# # Wstępne przygotowanei danych - preprocessing

# %%
df_raw.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
df = df_raw.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17007 entries, 0 to 17006
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   URL                           17007 non-null  object
#  1   ID                            17007 non-null  int64
#  2   Name                          17007 non-null  object
#  3   Subtitle                      5261 non-null   object
#  4   Icon URL                      17007 non-null  object
#  5   Average User Rating           7561 non-null   float64
#  6   User Rating Count             7561 non-null   float64
#  7   Price                         16983 non-null  float64
#  8   In-app Purchases              7683 non-null   object
#  9   Description                   17007 non-null  object
#  10  Developer                     17007 non-null  object
#  11  Age Rating                    17007 non-null  object
# ...

# %%
df = df.drop(columns = ['URL', 'Icon URL', 'Subtitle', 'Description', 'In-app Purchases'])

# %%
df.set_index('ID', inplace = True)
df.head()
# Out:
#                     Name  Average User Rating  User Rating Count  Price  \
# ID
# 284921427         Sudoku                 4.00            3553.00   2.99
# 284926400        Reversi                 3.50             284.00   1.99
# 284946595        Morocco                 3.00            8376.00   0.00
# 285755462  Sudoku (Free)                 3.50          190394.00   0.00
# 285831220   Senet Deluxe                 3.50              28.00   2.99
#
#                           Developer Age Rating  \
# ID
# 284921427  Mighty Mighty Good Games         4+
# 284926400          Kiss The Machine         4+
# 284946595               Bayou Games         4+
# 285755462  Mighty Mighty Good Games         4+
# 285831220           RoGame Software         4+
#
#                                                    Languages        Size  \
# ID
# 284921427  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT... 15853568.00
# 284926400                                                 EN 12328960.00
# ...

# %%
df.describe().T
# Out:
#                        count         mean          std      min         25%  \
# Average User Rating  7561.00         4.06         0.75     1.00        3.50
# User Rating Count    7561.00      3306.53     42322.56     5.00       12.00
# Price               16983.00         0.81         7.84     0.00        0.00
# Size                17006.00 115706429.89 203647677.85 51328.00 22950144.00
#
#                             50%          75%           max
# Average User Rating        4.50         4.50          5.00
# User Rating Count         46.00       309.00    3032734.00
# Price                      0.00         0.00        179.99
# Size                56768954.00 133027072.00 4005591040.00

# %%
df.describe(include = ['object']).T
# Out:
#                               count unique  \
# Name                          17007  16847
# Developer                     17007   8693
# Age Rating                    17007      4
# Languages                     16947    990
# Primary Genre                 17007     21
# Genres                        17007   1004
# Original Release Date         17007   3084
# Current Version Release Date  17007   2512
#
#                                                                      top  \
# Name                                                           Additions
# Developer                     Tapps Tecnologia da Informa\xe7\xe3o Ltda.
# Age Rating                                                            4+
# Languages                                                             EN
# Primary Genre                                                      Games
# Genres                                           Games, Strategy, Puzzle
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Average User Rating', 'User Rating Count', 'Price',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
df.columns = [col.lower().replace(' ', '_') for col in df.columns]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17007 entries, 284921427 to 1475076711
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          17007 non-null  object
#  1   average_user_rating           7561 non-null   float64
#  2   user_rating_count             7561 non-null   float64
#  3   price                         16983 non-null  float64
#  4   developer                     17007 non-null  object
#  5   age_rating                    17007 non-null  object
#  6   languages                     16947 non-null  object
#  7   size                          17006 non-null  float64
#  8   primary_genre                 17007 non-null  object
#  9   genres                        17007 non-null  object
#  10  original_release_date         17007 non-null  object
#  11  current_version_release_date  17007 non-null  object
# ...

# %% [markdown]
# # Jak zbadać rozkład zmiennych

# %%
df.primary_genre.value_counts()
# Out:
# Games                16286
# Education              222
# Entertainment          198
# Utilities               77
# Sports                  60
# Reference               32
# Stickers                29
# Finance                 18
# Business                16
# Productivity            15
# Lifestyle               10
# Book                     9
# Social Networking        9
# News                     7
# Health & Fitness         5
# Food & Drink             4
# Music                    3
# Navigation               3
# Medical                  2
# Travel                   1
# Shopping                 1
# Name: primary_genre, dtype: int64

# %%
# Jak np. wydobyć 5 najbardziej popularnych gatunków?
df.primary_genre.value_counts().nlargest(5)
# Out:
# Games            16286
# Education          222
# Entertainment      198
# Utilities           77
# Sports              60
# Name: primary_genre, dtype: int64

# %%
# Jak np. wydobyć 5 najbardziej popularnych gatunków?
df.primary_genre.value_counts().nlargest(5).index
# Out:
# Index(['Games', 'Education', 'Entertainment', 'Utilities', 'Sports'], dtype='object')

# %%
list(df.primary_genre.value_counts().nlargest(5).index)
# Out:
# ['Games', 'Education', 'Entertainment', 'Utilities', 'Sports']

# %%
df.age_rating.value_counts()
# Out:
# 4+     11806
# 9+      2481
# 12+     2055
# 17+      665
# Name: age_rating, dtype: int64

# %%
import seaborn as sns
sns.set()

_ = df.age_rating.value_counts().plot(kind = 'bar')

# %%
_ = df.age_rating.value_counts().plot(kind = 'pie')

# %%
df.price
# Out:
# ID
# 284921427    2.99
# 284926400    1.99
# 284946595    0.00
# 285755462    0.00
# 285831220    2.99
#              ...
# 1474626442   0.00
# 1474919257   0.00
# 1474962324   0.00
# 1474963671   0.00
# 1475076711   0.00
# Name: price, Length: 17007, dtype: float64

# %%
df.price.value_counts()
# Out:
# 0.00      14212
# 0.99       1078
# 1.99        515
# 2.99        471
# 4.99        237
# 3.99        163
# 9.99         88
# 11.99        59
# 5.99         42
# 6.99         32
# 179.99       30
# 7.99         17
# 8.99         13
# 19.99         9
# 14.99         4
# 12.99         3
# 16.99         2
# 29.99         2
# 139.99        1
# 99.99         1
# 37.99         1
# 36.99         1
# 18.99         1
# 59.99         1
# Name: price, dtype: int64

# %%
df.average_user_rating.value_counts()
# Out:
# 4.50    2861
# 4.00    1722
# 5.00     990
# 3.50     925
# 3.00     514
# 2.50     317
# 2.00     158
# 1.50      60
# 1.00      14
# Name: average_user_rating, dtype: int64

# %%
df.languages
# Out:
# ID
# 284921427     DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...
# 284926400                                                    EN
# 284946595                                                    EN
# 285755462     DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...
# 285831220     DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...
#                                     ...
# 1474626442                                                   EN
# 1474919257                                                   EN
# 1474962324                                                   EN
# 1474963671                                                   EN
# 1475076711                                               EN, ZH
# Name: languages, Length: 17007, dtype: object

# %%
df.languages.value_counts()
# Out:
# EN                                                                            12467
# EN, ZH                                                                          354
# CS, NL, EN, FR, DE, IT, JA, KO, PL, PT, RU, ZH, ES, SV, ZH, TR                  277
# EN, ZH, ZH                                                                      248
# EN, DE                                                                          147
#                                                                               ...
# DA, NL, EN, FI, FR, DE, IT, JA, KO, NO, PL, PT, RU, ZH, ES, SV, ZH, TR, UK        1
# EN, FR, IT, JA, KO, PT, RU, ES, TR                                                1
# DA, NL, EN, FR, DE, IT, NB, PL, PT, ZH, ES, SV, ZH, TR                            1
# EN, PT, ZH                                                                        1
# AR, NL, EN, FR, DE, ID, IT, JA, KO, PT, RU, ZH, ES, SV, TH, ZH, TR, VI            1
# Name: languages, Length: 990, dtype: int64

# %%
df.languages.str.split(', ')
# Out:
# ID
# 284921427     [DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, P...
# 284926400                                                  [EN]
# 284946595                                                  [EN]
# 285755462     [DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, P...
# 285831220     [DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, R...
#                                     ...
# 1474626442                                                 [EN]
# 1474919257                                                 [EN]
# 1474962324                                                 [EN]
# 1474963671                                                 [EN]
# 1475076711                                             [EN, ZH]
# Name: languages, Length: 17007, dtype: object

# %%
df.languages.str.split(', ').str.len()
# Out:
# ID
# 284921427    17.00
# 284926400     1.00
# 284946595     1.00
# 285755462    17.00
# 285831220    15.00
#               ...
# 1474626442    1.00
# 1474919257    1.00
# 1474962324    1.00
# 1474963671    1.00
# 1475076711    2.00
# Name: languages, Length: 17007, dtype: float64

# %%
df['num_lang'] = df.languages.str.split(', ').str.len()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17007 entries, 284921427 to 1475076711
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          17007 non-null  object
#  1   average_user_rating           7561 non-null   float64
#  2   user_rating_count             7561 non-null   float64
#  3   price                         16983 non-null  float64
#  4   developer                     17007 non-null  object
#  5   age_rating                    17007 non-null  object
#  6   languages                     16947 non-null  object
#  7   size                          17006 non-null  float64
#  8   primary_genre                 17007 non-null  object
#  9   genres                        17007 non-null  object
#  10  original_release_date         17007 non-null  object
#  11  current_version_release_date  17007 non-null  object
# ...

# %%
df.num_lang.value_counts()
# Out:
# 1.00      12566
# 2.00       1102
# 3.00        495
# 16.00       316
# 4.00        261
# 5.00        247
# 6.00        220
# 25.00       171
# 9.00        154
# 11.00       147
# 8.00        142
# 7.00        140
# 10.00       140
# 31.00       133
# 12.00        91
# 21.00        77
# 14.00        64
# 13.00        64
# 15.00        54
# 17.00        37
# 30.00        35
# 19.00        34
# 32.00        34
# 33.00        33
# 22.00        31
# 18.00        24
# 46.00        20
# 26.00        18
# 20.00        14
# 24.00        13
# 23.00        11
# 27.00        11
# 28.00         9
# 29.00         8
# 45.00         6
# 44.00         5
# 65.00         4
# 42.00         3
# 43.00         3
# 36.00         2
# 49.00         2
# 48.00         1
# 66.00         1
# 35.00         1
# 34.00         1
# 111.00        1
# 76.00         1
# Name: num_lang, dtype: int64

# %% [markdown]
# # Sprawdzanie braków danych

# %%
df.info() # tutaj mogę sprawdzić 'ręcznie' ile braków mam w danych
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17007 entries, 284921427 to 1475076711
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          17007 non-null  object
#  1   average_user_rating           7561 non-null   float64
#  2   user_rating_count             7561 non-null   float64
#  3   price                         16983 non-null  float64
#  4   developer                     17007 non-null  object
#  5   age_rating                    17007 non-null  object
#  6   languages                     16947 non-null  object
#  7   size                          17006 non-null  float64
#  8   primary_genre                 17007 non-null  object
#  9   genres                        17007 non-null  object
#  10  original_release_date         17007 non-null  object
#  11  current_version_release_date  17007 non-null  object
# ...

# %%
df.average_user_rating.value_counts(dropna = False)
# Out:
# NaN     9446
# 4.50    2861
# 4.00    1722
# 5.00     990
# 3.50     925
# 3.00     514
# 2.50     317
# 2.00     158
# 1.50      60
# 1.00      14
# Name: average_user_rating, dtype: int64

# %%
df.isnull().head() # metoda pokazuje gdzie są braki
# Out:
#             name  average_user_rating  user_rating_count  price  developer  \
# ID
# 284921427  False                False              False  False      False
# 284926400  False                False              False  False      False
# 284946595  False                False              False  False      False
# 285755462  False                False              False  False      False
# 285831220  False                False              False  False      False
#
#            age_rating  languages   size  primary_genre  genres  \
# ID
# 284921427       False      False  False          False   False
# 284926400       False      False  False          False   False
# 284946595       False      False  False          False   False
# 285755462       False      False  False          False   False
# 285831220       False      False  False          False   False
#
#            original_release_date  current_version_release_date  num_lang
# ID
# ...

# %%
df.isnull().sum() # zwróci nam dokładne informaje na temat braków danych w poszczególnych kolumnach
# Out:
# name                               0
# average_user_rating             9446
# user_rating_count               9446
# price                             24
# developer                          0
# age_rating                         0
# languages                         60
# size                               1
# primary_genre                      0
# genres                             0
# original_release_date              0
# current_version_release_date       0
# num_lang                          60
# dtype: int64

# %%
df = df.dropna() # trzeba pamiętać że funkcja dropna() usuwa CAŁY WIERSZ jeśli w którejś z kolumn jest jakikolwiek brak
df.isnull().sum()
# Out:
# name                            0
# average_user_rating             0
# user_rating_count               0
# price                           0
# developer                       0
# age_rating                      0
# languages                       0
# size                            0
# primary_genre                   0
# genres                          0
# original_release_date           0
# current_version_release_date    0
# num_lang                        0
# dtype: int64

# %% [markdown]
# # DataFrame: porównanie do SQL

# %%
import numpy as np
import pandas as pd

# %%
url = ('https://storage.googleapis.com/esmartdata-courses-files/ds-bootcamp/online_retail.xlsx')
retail_raw = pd.read_excel(url)
retail_raw.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55    17850.00  United Kingdom
# 1 2010-12-01 08:26:00       3.39    17850.00  United Kingdom
# 2 2010-12-01 08:26:00       2.75    17850.00  United Kingdom
# 3 2010-12-01 08:26:00       3.39    17850.00  United Kingdom
# 4 2010-12-01 08:26:00       3.39    17850.00  United Kingdom

# %%
retail = retail_raw.copy()
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
retail.describe().T
# Out:
#                count     mean     std       min      25%      50%      75%  \
# Quantity   541909.00     9.55  218.08 -80995.00     1.00     3.00    10.00
# UnitPrice  541909.00     4.61   96.76 -11062.06     1.25     2.08     4.13
# CustomerID 406829.00 15287.69 1713.60  12346.00 13953.00 15152.00 16791.00
#
#                 max
# Quantity   80995.00
# UnitPrice  38970.00
# CustomerID 18287.00

# %%
retail.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
retail.dropna(inplace = True)
retail.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
retail = retail[retail.Quantity >= 0]
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397924 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397924 non-null  object
#  1   StockCode    397924 non-null  object
#  2   Description  397924 non-null  object
#  3   Quantity     397924 non-null  int64
#  4   InvoiceDate  397924 non-null  datetime64[ns]
#  5   UnitPrice    397924 non-null  float64
#  6   CustomerID   397924 non-null  float64
#  7   Country      397924 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.3+ MB

# %%
retail.CustomerID = retail.CustomerID.apply(lambda x: str(int(x)))
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397924 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397924 non-null  object
#  1   StockCode    397924 non-null  object
#  2   Description  397924 non-null  object
#  3   Quantity     397924 non-null  int64
#  4   InvoiceDate  397924 non-null  datetime64[ns]
#  5   UnitPrice    397924 non-null  float64
#  6   CustomerID   397924 non-null  object
#  7   Country      397924 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 27.3+ MB

# %% [markdown]
# # Porównanie do języka SQL

# %%
# SELECT * FROM retail;
retail
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# ...

# %%
# SELECT Quantity, UnitPrice, CustomerID FROM retail;
retail[['Quantity', 'UnitPrice', 'CustomerID']]
# Out:
#         Quantity  UnitPrice CustomerID
# 0              6       2.55      17850
# 1              6       3.39      17850
# 2              8       2.75      17850
# 3              6       3.39      17850
# 4              6       3.39      17850
# ...          ...        ...        ...
# 541904        12       0.85      12680
# 541905         6       2.10      12680
# 541906         4       4.15      12680
# 541907         4       4.15      12680
# 541908         3       4.95      12680
#
# [397924 rows x 3 columns]

# %%
# SELECT Quantity, UnitPrice, CustomerID FROM retail LIMIT 10;
retail[['Quantity', 'UnitPrice', 'CustomerID']].head(10)
retail[['Quantity', 'UnitPrice', 'CustomerID']][:10]
# Out:
#    Quantity  UnitPrice CustomerID
# 0         6       2.55      17850
# 1         6       3.39      17850
# 2         8       2.75      17850
# 3         6       3.39      17850
# 4         6       3.39      17850
# 5         2       7.65      17850
# 6         6       4.25      17850
# 7         6       1.85      17850
# 8         6       1.85      17850
# 9        32       1.69      13047

# %%
# SELECT * FROM retail WHERE CustomerID = '17850';
retail[retail.CustomerID == '17850'] #maskowanie logiczne
retail.query('CustomerID == "17850"') # metoda query
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 4540    536790     22752         SET 7 BABUSHKA NESTING BOXES         4
# 4541    536790     22803             IVORY EMBROIDERED QUILT          3
# 4542    536790     21730    GLASS STAR FROSTED T-LIGHT HOLDER        12
# 4543    536791     22632            HAND WARMER RED POLKA DOT        12
# 4544    536791     22633               HAND WARMER UNION JACK        12
#
#              InvoiceDate  UnitPrice CustomerID         Country
# ...

# %%
# SELECT * FROM retail WHERE CustomerID = '17850' and UnitPrice > 5;
retail[(retail.CustomerID == '17850') & (retail.UnitPrice > 5)].head() # head tylko po to żeby nie wyświetlać wszystkich wierszy
# Out:
#    InvoiceNo StockCode                        Description  Quantity  \
# 5     536365     22752       SET 7 BABUSHKA NESTING BOXES         2
# 58    536373     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 63    536373     22752       SET 7 BABUSHKA NESTING BOXES         2
# 75    536375     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 80    536375     22752       SET 7 BABUSHKA NESTING BOXES         2
#
#            InvoiceDate  UnitPrice CustomerID         Country
# 5  2010-12-01 08:26:00       7.65      17850  United Kingdom
# 58 2010-12-01 09:02:00       6.95      17850  United Kingdom
# 63 2010-12-01 09:02:00       7.65      17850  United Kingdom
# 75 2010-12-01 09:32:00       6.95      17850  United Kingdom
# 80 2010-12-01 09:32:00       7.65      17850  United Kingdom

# %%
# SELECT * FROM retail WHERE CustomerID = '17850' or Country = 'France';
retail[(retail.CustomerID == '17850') | (retail.Country == 'France')] # metoda maski logicznej
retail.query('CustomerID == "17850" | Country == "France"') # metoda query
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# ...

# %%
# SELECT * FROM retail WHERE InvoiceNo is not null;
retail[retail.InvoiceNo.notnull()]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# ...

# %%
# SELECT CustomerID, count(*) FROM retail GROUP BY CustomerID;
retail.groupby('CustomerID').size()
# Out:
# CustomerID
# 12346      1
# 12347    182
# 12348     31
# 12349     73
# 12350     17
#         ...
# 18280     10
# 18281      7
# 18282     12
# 18283    756
# 18287     70
# Length: 4339, dtype: int64

# %%
# SELECT CustomerID, avg(Revenue), count(*) FROM retail GROUP BY CustomerID;
retail['Revenue'] = retail.Quantity * retail.UnitPrice # Najpierw tworzę kolumnę Revenue, ponieważ nie posiadam takiej
retail.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice CustomerID         Country  Revenue
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom    22.00

# %%
retail.groupby('CustomerID').aggregate({'Revenue' : np.mean,
                                        'CustomerID' : np.size}).head(3)
# Out:
#             Revenue  CustomerID
# CustomerID
# 12346      77183.60           1
# 12347         23.68         182
# 12348         57.98          31

# %%
retail.groupby('CustomerID').aggregate({'Revenue' : np.mean,
                                        'CustomerID' : np.size}).head(3). \
    rename(columns = {'Revenue': 'RevenueAverage',
                      'CustomerID' : 'CustomerIDCount'})
# Out:
#             RevenueAverage  CustomerIDCount
# CustomerID
# 12346             77183.60                1
# 12347                23.68              182
# 12348                57.98               31

# %%
# SELECT InvoiceDateDay, sum(Revenue) FROM retail GROUP BY InvoiceDateDay;
retail['InvoiceDateDay'] = retail.InvoiceDate.dt.day # najpierw stworzę nową kolumnę, która będzie zawierała dzień
retail.head(2)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Revenue  \
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34
#
#    InvoiceDateDay
# 0               1
# 1               1

# %%
results = retail.groupby('InvoiceDateDay').aggregate({'Revenue' : np.sum})

# %%
import seaborn as sns
sns.set()

results.plot(kind = 'bar')
# Out:
# <Axes: xlabel='InvoiceDateDay'>

# %%
# SELECT * FROM retail ORDER BY Quantity DESC LIMIT 5;
retail.nlargest(n = 5, columns = 'Quantity')
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 540421    581483     23843        PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431     23166     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 502122    578841     84826     ASSTD DESIGN 3D PAPER STICKERS     12540
# 421632    573008     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 206121    554868     22197               SMALL POPCORN HOLDER      4300
#
#                InvoiceDate  UnitPrice CustomerID         Country   Revenue  \
# 540421 2011-12-09 09:15:00       2.08      16446  United Kingdom 168469.60
# 61619  2011-01-18 10:01:00       1.04      12346  United Kingdom  77183.60
# 502122 2011-11-25 15:57:00       0.00      13256  United Kingdom      0.00
# 421632 2011-10-27 12:26:00       0.21      12901  United Kingdom   1008.00
# 206121 2011-05-27 10:52:00       0.72      13135  United Kingdom   3096.00
#
#         InvoiceDateDay
# 540421               9
# 61619               18
# ...

# %%
# SELECT * FROM retail ORDER BY Quantity LIMIT 5;
retail.nsmallest(n=5, columns = 'Quantity')
# Out:
#     InvoiceNo StockCode                      Description  Quantity  \
# 113    536381     71270                  PHOTO CLIP LINE         1
# 114    536381     22262            FELT EGG COSY CHICKEN         1
# 115    536381     22637            PIGGY BANK RETROSPOT          1
# 118    536381     21166       COOK WITH WINE METAL SIGN          1
# 120    536381    37444A  YELLOW BREAKFAST CUP AND SAUCER         1
#
#             InvoiceDate  UnitPrice CustomerID         Country  Revenue  \
# 113 2010-12-01 09:41:00       1.25      15311  United Kingdom     1.25
# 114 2010-12-01 09:41:00       0.85      15311  United Kingdom     0.85
# 115 2010-12-01 09:41:00       2.55      15311  United Kingdom     2.55
# 118 2010-12-01 09:41:00       1.95      15311  United Kingdom     1.95
# 120 2010-12-01 09:41:00       2.95      15311  United Kingdom     2.95
#
#      InvoiceDateDay
# 113               1
# 114               1
# 115               1
# 118               1
# 120               1
